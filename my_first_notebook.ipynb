# %%
Hardware refers to the physical parts of a computer that we can see and touch, such as a keyboard. Software refers to programs or instructions that run on a computer and cannot be touched, such as Microsoft Word. Both hardware and software work together to make a computer function.
